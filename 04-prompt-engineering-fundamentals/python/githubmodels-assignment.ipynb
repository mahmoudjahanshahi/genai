# %% [markdown]
# # Introduction to Prompt Engineering
# Prompt engineering is the process of designing and optimizing prompts for natural language processing tasks. It involves selecting the right prompts, tuning their parameters, and evaluating their performance. Prompt engineering is crucial for achieving high accuracy and efficiency in NLP models. In this section, we will explore the basics of prompt engineering using the OpenAI models for exploration.

# %% [markdown]
# ### Exercise 1: Tokenization
# Explore Tokenization using tiktoken, an open-source fast tokenizer from OpenAI
# See [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) for more examples.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]
# Out:
# [198, 41, 20089, 374, 279, 18172, 11841, 505, 279, 8219, 323, 279, 7928, 304, 279, 25450, 744, 13, 1102, 374, 264, 6962, 14880, 449, 264, 3148, 832, 7716, 52949, 339, 430, 315, 279, 8219, 11, 719, 1403, 9976, 7561, 34902, 3115, 430, 315, 682, 279, 1023, 33975, 304, 279, 25450, 744, 11093, 13, 50789, 374, 832, 315, 279, 72021, 6302, 9621, 311, 279, 19557, 8071, 304, 279, 3814, 13180, 11, 323, 706, 1027, 3967, 311, 14154, 86569, 2533, 1603, 12715, 3925, 13, 1102, 374, 7086, 1306, 279, 13041, 10087, 50789, 8032, 777, 60, 3277, 19894, 505, 9420, 11, 50789, 649, 387, 10107, 3403, 369, 1202, 27000, 3177, 311, 6445, 9621, 35612, 17706, 508, 60, 323, 374, 389, 5578, 279, 4948, 1481, 1315, 478, 5933, 1665, 304, 279, 3814, 13180, 1306, 279, 17781, 323, 50076, 627]
# [b'\n',
#  b'J',
#  b'upiter',
#  b' is',
#  b' the',
#  b' fifth',
#  b' planet',
#  b' from',
#  b' the',
#  b' Sun',
#  b' and',
#  b' the',
#  b' largest',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b'.',
#  b' It',
#  b' is',
#  b' a',
#  b' gas',
#  b' giant',
#  b' with',
#  b' a',
#  b' mass',
#  b' one',
#  b'-th',
#  b'ousand',
#  b'th',
#  b' that',
#  b' of',
#  b' the',
#  b' Sun',
#  b',',
#  b' but',
#  b' two',
#  b'-and',
#  b'-a',
#  b'-half',
#  b' times',
#  b' that',
#  b' of',
#  b' all',
#  b' the',
#  b' other',
#  b' planets',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b' combined',
#  b'.',
#  b' Jupiter',
#  b' is',
#  b' one',
#  b' of',
#  b' the',
#  b' brightest',
#  b' objects',
#  b' visible',
#  b' to',
#  b' the',
#  b' naked',
#  b' eye',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b',',
#  b' and',
#  b' has',
#  b' been',
#  b' known',
#  b' to',
#  b' ancient',
#  b' civilizations',
#  b' since',
#  b' before',
#  b' recorded',
#  b' history',
#  b'.',
#  b' It',
#  b' is',
#  b' named',
#  b' after',
#  b' the',
#  b' Roman',
#  b' god',
#  b' Jupiter',
#  b'.[',
#  b'19',
#  b']',
#  b' When',
#  b' viewed',
#  b' from',
#  b' Earth',
#  b',',
#  b' Jupiter',
#  b' can',
#  b' be',
#  b' bright',
#  b' enough',
#  b' for',
#  b' its',
#  b' reflected',
#  b' light',
#  b' to',
#  b' cast',
#  b' visible',
#  b' shadows',
#  b',[',
#  b'20',
#  b']',
#  b' and',
#  b' is',
#  b' on',
#  b' average',
#  b' the',
#  b' third',
#  b'-b',
#  b'right',
#  b'est',
#  b' natural',
#  b' object',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b' after',
#  b' the',
#  b' Moon',
#  b' and',
#  b' Venus',
#  b'.\n']

# %% [markdown]
# ### Exercise 2: Validate Github Models Key Setup
#
# Run the code below to verify that your Github Models endpoint is set up correctly. The code just tries a simple basic prompt and validates the completion. Input `oh say can you see` should complete along the lines of `by the dawn's early light..`

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

token = os.environ["GITHUB_TOKEN"]
endpoint = "https://models.inference.ai.azure.com"

model_name = "gpt-4o"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

def get_completion(prompt, client, model_name, temperature=1.0, max_tokens=1000, top_p=1.0):
    response = client.complete(
        messages=[
            {
                "role": "system",
                "content": "You are a helpful assistant.",
            },
            {
                "role": "user",
                "content": prompt,
            },
        ],
        model=model_name,
        temperature=temperature,
        max_tokens=max_tokens,
        top_p=top_p
    )
    return response.choices[0].message.content

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Oh, say can you see,
# By the dawn's early light,
# What so proudly we hailed
# At the twilight's last gleaming?
#
# Perhaps you're referencing the opening lines of the U.S. national anthem, *The Star-Spangled Banner*! Let me know if you'd like more information or if I can assist with something else! 😊

# %% [markdown]
# ### Exercise 3: Fabrications
# Explore what happens when you ask the LLM to return completions for a prompt about a topic that may not exist, or about topics that it may not know about because it was outside it's pre-trained dataset (more recent). See how the response changes if you try a different prompt, or a different model.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
# Out:
# It appears that the "Martian War of 2076" is fictional, as no historical or scientific records mention such an event—at least up to my knowledge cutoff in October 2023. However, I can help you create a creative, speculative, or science-fiction-themed lesson plan based on this concept. The lesson plan can incorporate elements of science, history, creative writing, or even futuristic political studies. Let’s dive in:
#
# ---
#
# ### Lesson Plan: **The Martian War of 2076 – Exploring a Speculative Future**
#
# #### Grade Level:
# Middle School - High School (adjustable based on depth)
#
# #### Subject:
# Interdisciplinary Lesson Plan (combining History, Science, and Creative Writing)
#
# ---
#
# ### Learning Objectives:
# By the end of this lesson, students will:
# 1. Understand the implications of interplanetary colonization and the potential for conflicts in space.
# 2. Analyze how historical patterns of war and diplomacy on Earth could apply to futuristic scenarios.
# 3. Use critical thinking to imagine and debate ethical dilemmas of war in a space-faring civilization.
# 4. Practice storytelling and creative writing to envision a science-fictional historical event.
#
# ---
#
# ### Materials Needed:
# - Whiteboard/Smartboard
# - Research materials on space exploration, Mars colonization, and modern geopolitics
# - Handouts on historical parallels (e.g., the American Revolution, or the Cold War)
# - Art supplies for map-making and posters (optional)
# - Writing tools or devices for essay writing
# - Videos about space technology, Mars, and speculative futures (e.g., clips from *The Martian* or *Interstellar*)
#
# ---
#
# ### Lesson Duration:
# 1-hour lesson (or stretched over multiple class periods if desired)
#
# ---
#
# ### Lesson Outline
#
# #### 1. Warm-Up Discussion (10 minutes)
# - Begin with a provocative question: "What would happen if humans colonized Mars? Would we live in total peace, or could conflict arise?"
# - Discuss how history has shown that once people expand into new territories (e.g., colonization on Earth), conflicts sometimes follow.
# - Introduce the idea of the Martian War of 2076 as a thought experiment.
#
# #### 2. Historical Context & Parallels (15 minutes)
# - Share examples of Earth-based history that might be analogous to interplanetary tensions:
#   - Colonial uprisings (American Revolution, Indian independence movement)
#   - Cold War tensions between superpowers
#   - Resource-driven conflicts (e.g., wars over gold, oil, or water)
# - Discuss how conflicts over limited resources, governance, or cultural differences could mirror those situations in a Martian setting.
#
# #### 3. Science and Space Exploration (15 minutes)
# - Provide a short overview of:
#   - Current Mars exploration programs (NASA, SpaceX, European Space Agency)
#   - Challenges of living on Mars (limited resources, harsh environmental conditions)
#   - The potential for cooperation or competition between countries and private corporations in space colonization.
# - Pose a question: "How could these factors contribute to a war on Mars in 2076? What might trigger it?"
#
# #### 4. Creative Activity: Story or Debate (20 minutes)
# Choose one of the following:
#
# - **Option A: Collaborative Sci-Fi Storytelling**
#   - Ask students to work in small groups to create a fictional account of the Martian War of 2076.
#   - Have them answer key questions:
#     - What started the war? (resources, ideology, independence?)
#     - Who were the key players? (Earth nations, Martian colonies, private corporations?)
#     - What technology or strategies were used?
#     - What was the resolution—if any?
#
# - **Option B: Debate**
#   - Divide the class into two teams:
#     - One team represents Martian colonists seeking independence.
#     - The other team represents Earth-based governments or corporations controlling Mars’ resources.
#   - Debate prompt: "Should Martian colonies have the right to self-govern, or does Earth retain control since they funded the colonization?"
#
# ---
#
# ### Homework/Extension:
# - **Writing Assignment:** Ask students to write a 1-2 page historical account (as if they were living in the 22nd century) reflecting on the causes, events, and outcomes of the Martian War of 2076. Encourage them to include firsthand "interviews" with fictional participants, maps, or diary entries.
# - **Optional Research Task:** Have students investigate current Mars missions and write a report on how feasible colonization really is.
#
# ---
#
# ### Assessment:
# - Evaluate based on participation in discussions and storytelling/debate activities.
# - Assess homework for creativity, understanding of historical and futuristic concepts, and ability to draw parallels between Earth’s history and a speculative future.
#
# ---
#
# ### Reflection:
# Wrap up by asking students: "What can we learn about future conflicts by studying the past? How does thinking about the Martian War of 2076 teach us about our responsibilities as

# %% [markdown]
# ### Exercise 4: Instruction Based
# Use the "text" variable to set the primary content
# and the "prompt" variable to provide an instruction related to that primary content.
#
# Here we ask the model to summarize the text for a second-grade student

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Jupiter is the fifth planet from the Sun and the biggest planet in our Solar System. It's made of gas and is much, much bigger than all the other planets put together! People have known about Jupiter for a very long time, even before history was written down. It's named after a Roman god. At night, Jupiter is so bright that you can see it without a telescope, and it’s the third brightest thing in the sky after the Moon and Venus.

# %% [markdown]
# ### Exercise 5: Complex Prompt
# Try a request that has system, user and assistant messages
# System sets assistant context
# User & Assistant messages provide multi-turn conversation context
#
# Note how the assistant personality is set to "sarcastic" in the system context.
# Try using a different personality context. Or try a different series of input/output messages

# %%
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Oh, you mean the 2020 World Series—the one held during the "cardboard fans and fake crowd noise" era? That iconic series was played at Globe Life Field in Arlington, Texas. Because, you know, nothing screams Dodgers baseball like neutral-site games in a brand-new stadium miles away from Los Angeles... thanks, pandemic.

# %% [markdown]
# ### Exercise: Explore Your Intuition
# The above examples give you patterns that you can use to create new prompts (simple, complex, instruction etc.) - try creating other exercises to explore some of the other ideas we've talked about like examples, cues and more.
